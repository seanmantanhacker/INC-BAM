# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# add parent folder (production) to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAM

import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# c:\Users\LENOVO\SEAN\PNU-2025\INC\INC-BAM\utils\my_lora_utils.py

# %%
# ---- Example usage with your LoRa generator ----
sf = 9
bw = 125000
fs = 1_000_000
lora_init = LoRa(sf, bw)
x1 = lora_init.gen_symbol_fs(0, sf, bw, down=False, Fs=fs) # you had Fs=int(bw*8)=1e6
snr = 0
x = lora_init.awgn_iq(x1,snr)

PLOT_SPECGRAM(x,128,"spectrogram",32,fs)
# LoRa Parameters
symbol_time = 2**sf / bw  # Symbol duration
# Time vector
t = np.arange(0, symbol_time, 1/fs)
y = generate_lora_chirp(1,t)
y_a = awgn(y,snr)

PLOT_SPECGRAM(y_a,128,"spectrogram",32,fs)

# %%
file_path = "dataset_new_sf9/s_sf9_bw125_-5_0_1.npy"  # example path
data2 = np.load(file_path)

show_multiple_spectrograms([data2],["a"],1)
print(data2.shape)
print(data2.dtype)
print(data2)
print(data2.mean())

print(data2.min())

print(data2.max())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 file_path = "dataset_new_sf9/s_sf9_bw125_-5_0_1.npy"  # example path
# ----> 2 data2 = np.load(file_path)
#       4 show_multiple_spectrograms([data2],["a"],1)
#       5 print(data2.shape)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset_new_sf9/s_sf9_bw125_-5_0_1.npy'
